# %% [markdown]
# Implement the card game war. Rules are:
#
# 1. Deal out deck of 52 cards between two users.
# 2. Each player plays a card. Higher card wins. Winner takes both cards.
# 3. If players tie, then each player puts down three cards, and the third
#    card competes.
#    If a player has less than 3 cards, then they put down all of their cards
#    and their final card competes against the other player's third card.
#    Continue doing this until tie is broken.
#    Winner takes all cards.
# 4. Game is over when a player doesn't have any cards. The player with
#    cards remaining is the winner.

# %%
# Card:52 deck
# suit: diamond, club,...
# rank: one,two,...jack, queen, king, ace
# value = integer value related to the rank 

import random

# tuples of suits
suits = ('Hearts','Diamonds','Spades','Clubs')

# ranks of the crads
ranks = ('Two','Three','Four','Five','Six','Seven','Eight','Nine','Ten','Jack','Queen','King','Ace')

# Global variable
# cretae a dictionery for cards
values = {'Two' : 2 , 'Three': 3, 'Four':4, 'Five' : 5, 'Six' : 6, 'Seven' : 7, 'Eight':8,'Nine':9, 'Ten':10,'Jack':11,
          'Queen':12,'King':13,'Ace':14}

# %%
# the card function to cretae 52 deck cards
class Card():
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
        
    def __str__(self):
        return self.rank + " of " + self.suit

# %%
# Deck class
# Instantiate a new deck
# cretae all 52 Card objects
# Holds as a list of card objects
# shuffels a deck through a method call
# Random libary shuffle() function
# Dela Cards from the deck object
# Pop method from cards list

class Deck:
    
    def __init__(self):
        self.all_cards = []
        
        for suit in suits:
            for rank in ranks:
                created_card = Card(suit,rank)
                #cretae the card object
                self.all_cards.append(created_card)
                
# shuffles all cards  
    def shuffle(self):
        random.shuffle(self.all_cards)
        
# remove select single card from 52 deck of cards   
    def deal_one(self):
        return self.all_cards.pop()

# %%
# player class
# This calss will be used to hold a player's current list of cards
# a player should be able to add or remove cards frpm their"hand"
# player can add a single card or multiple cards to  their list
# translating a Deck/hand of cards with a top and bottom to a Pythjon list

class Player():
    
    def __init__(self,name):
        self.name = name
        self.all_cards = []
        
    
    def remove_one(self):
        return self.all_cards.pop(0)
    
    
    def add_cards(self,new_cards):
        if type(new_cards) == type([]):
            #list of multiple  card objects
            self.all_cards.extend(new_cards)
        else:
            #for a single card object
            self.all_cards.append(new_cards)
        
    
    
    def __str__(self):
        return f'Palyer {self.name} has {len(self.all_cards)} cards.'

# %%
# Game setup
# create two player 
player_one = Player("One")
player_two = Player("Two")

new_deck = Deck()
new_deck.shuffle()


# split 52 decks of card between two players
for i in range(26):
    player_one.add_cards(new_deck.deal_one())
    player_two.add_cards(new_deck.deal_one())

# %%
# check cards 
print(len(player_one.all_cards))
print(player_one.all_cards[0])
# Out:
# 26
# Four of Diamonds

# %%
# while loop game_on
game_on = True

# %%
round_num = 0

while game_on:
    
    round_num += 1
    print(f'Round {round_num}')
    #
    if len(player_one.all_cards) == 0:
        print('Palyer One, out of cards! Palyer Two Wins')
        game_on = False
        break
    if len(player_two.all_cards) == 0:
        print('Palyer Two, out of cards! Palyer One Wins')
        game_on = False
        break
    
    # Start new round
    player_one_cards = []
    player_one_cards.append(player_one.remove_one())
    
    player_two_cards = []
    player_two_cards.append(player_two.remove_one())
    
    comparison = True
    
    while comparison:
        
        if player_one_cards[-1].value > player_two_cards[-1].value:
            
            player_one.add_cards(player_one_cards)
            player_one.add_cards(player_two_cards)
            
            comparison = False
            
        elif player_one_cards[-1].value < player_two_cards[-1].value:
            
              player_two.add_cards(player_one_cards)
              player_two.add_cards(player_two_cards)
            
              comparison = False
        else: 
            print("WAR!")
            
            if len(player_one_cards) < 3:
                print("player one unalbe to declare war ")
                print("Player Two Wins")
                game_on = False
                break
            
            elif len(player_two_cards) < 3:
                print("player two unalbe to declare war ")
                print("Player one Wins")
                game_on = False
                break
                
            else:
                for num in range(3):
                    player_one_cards.append(player_one.remove_one())
                    player_two_cards.append(player_two.remove_one())
# Out:
# Round 1
# Round 2
# Round 3
# Round 4
# Round 5
# Round 6
# Round 7
# Round 8
# Round 9
# Round 10
# Round 11
# Round 12
# Round 13
# Round 14
# Round 15
# Round 16
# Round 17
# WAR!
# player one unalbe to declare war
# Player Two Wins
